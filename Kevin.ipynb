# %%
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy
import os

# %%
csv_file = "postgres_zip_city.csv"
customer_data_df = pd.read_csv(csv_file)
#customer_data_df.head()

# %%
customer_data_df= customer_data_df.reset_index()

# %%
rds_connection_string = "bedlgjelgbrcba:62edbf5e39edf1ea129a38a5766d7354579374a6db487103a421c76fd47d78c3@ec2-184-73-232-93.compute-1.amazonaws.com:5432/dd4i4baf4sjibo"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['zip_vs_coordinates', 'city_zip_data', 'market_scraped_data']

# %%
city_zip_data = 'market_scraped_data'

# %%
# drop city_zip_data if it exist already
connection = engine.raw_connection()
cursor = connection.cursor()
command = "DROP TABLE IF EXISTS {};".format(city_zip_data)
cursor.execute(command)
connection.commit()
cursor.close()

# %%
engine.table_names()
# Out:
# ['test', 'zip_vs_coordinates']

# %%
# create 'city_zip_data' table and fill up data 
customer_data_df.to_sql('city_zip_data', engine, dtype={col_name: sqlalchemy.types.VARCHAR for col_name in customer_data_df})

# %%
customer_data_df=customer_data_df.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1aeba1ce7a7e> in <module>
# ----> 1 customer_data_df=customer_data_df.reset_index(drop=True, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
print(customer_data_df)
# Out:
# None

# %%
customer_data_df.to_sql('market_scraped_data', engine, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in customer_data_df})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-afcb10544fc4> in <module>
# ----> 1 customer_data_df.to_sql('market_scraped_data', engine, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in customer_data_df})
#
# AttributeError: 'NoneType' object has no attribute 'to_sql'

# %%
pd.read_sql_query('select * from market_scraped_data', con=engine).head()
# Out:
#    index price-off       quantity        sku                    store-address  \
# 0      0   76% off       In Stock  625412161    209 Lakeshore PkwyHomewood AL
# 1      1   76% off       In Stock  625412161      9248 Parkway EBirmingham AL
# 2      2   76% off       In Stock  625412161         890 Odum RdGardendale AL
# 3      3   76% off       In Stock  625412161    5335 Highway 280Birmingham AL
# 4      4   76% off  Limited Stock  625412161  2780 John Hawkins PkwyHoover AL
#
#   zip-code:
# 0     35209
# 1     35206
# 2     35071
# 3     35242
# 4     35244

# %%
import sqlalchemy

from sqlalchemy import Column, Integer, String, Float

from sqlalchemy.orm import Session

from sqlalchemy.ext.automap import automap_base

from sqlalchemy import create_engine, inspect

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['zip_vs_coordinates', 'city_zip_data', 'market_scraped_data']

# %%
columns = inspector.get_columns('city_zip_data')
print(columns[3]['name'])
# Out:
# zip

# %%
import re
zips = [re.sub("\'|\,|\(|\)", "", str(item)) for item in engine.execute('SELECT zip FROM city_zip_data LIMIT 40').fetchall()]
zips
# Out:
# ['35203',
#  '35813',
#  '36601',
#  '36119',
#  '99599',
#  '85225',
#  '86001',
#  '85296',
#  '85302',
#  '85201',
#  '85381',
#  '85026',
#  '85251',
#  '85282',
#  '85726',
#  '85364',
#  '72764',
#  '72903',
#  '72202',
#  '72764',
#  '92803',
#  '94509',
#  '93380',
#  '91706',
#  '90706',
#  '90201',
#  '94704',
#  '91505',
#  '91710',
#  '91709',
#  '91910',
#  '94520',
#  '91718',
#  '92628',
#  '94015',
#  '90241',
#  '91734',
#  '95624',
#  '92025',
#  '94533']

# %%
# !!! important the sku must be set as variable  !!!
sku = 625412161
for item in zips:
    command= 'curl --data ' + '"sku=' + str(sku) + '&zip=' + item + '" https://brickseek.com/walmart-inventory-checker? -o html'+ item +'.html'
    output=os.system(command)
    print(command)
# Out:
# curl --data "sku=625412161&zip=35203" https://brickseek.com/walmart-inventory-checker? -o html35203.html
# curl --data "sku=625412161&zip=35813" https://brickseek.com/walmart-inventory-checker? -o html35813.html
# curl --data "sku=625412161&zip=36601" https://brickseek.com/walmart-inventory-checker? -o html36601.html
# curl --data "sku=625412161&zip=36119" https://brickseek.com/walmart-inventory-checker? -o html36119.html
# curl --data "sku=625412161&zip=99599" https://brickseek.com/walmart-inventory-checker? -o html99599.html
# curl --data "sku=625412161&zip=85225" https://brickseek.com/walmart-inventory-checker? -o html85225.html
# curl --data "sku=625412161&zip=86001" https://brickseek.com/walmart-inventory-checker? -o html86001.html
# curl --data "sku=625412161&zip=85296" https://brickseek.com/walmart-inventory-checker? -o html85296.html
# curl --data "sku=625412161&zip=85302" https://brickseek.com/walmart-inventory-checker? -o html85302.html
# curl --data "sku=625412161&zip=85201" https://brickseek.com/walmart-inventory-checker? -o html85201.html
# curl --data "sku=625412161&zip=85381" https://brickseek.com/walmart-inventory-checker? -o html85381.html
# curl --data "sku=625412161&zip=85026" https://brickseek.com/walmart-inventory-checker? -o html85026.html
# curl --data "sku=625412161&zip=85251" https://brickseek.com/walmart-inventory-checker? -o html85251.html
# curl --data "sku=625412161&zip=85282" https://brickseek.com/walmart-inventory-checker? -o html85282.html
# curl --data "sku=625412161&zip=85726" https://brickseek.com/walmart-inventory-checker? -o html85726.html
# curl --data "sku=625412161&zip=85364" https://brickseek.com/walmart-inventory-checker? -o html85364.html
# curl --data "sku=625412161&zip=72764" https://brickseek.com/walmart-inventory-checker? -o html72764.html
# curl --data "sku=625412161&zip=72903" https://brickseek.com/walmart-inventory-checker? -o html72903.html
# curl --data "sku=625412161&zip=72202" https://brickseek.com/walmart-inventory-checker? -o html72202.html
# curl --data "sku=625412161&zip=72764" https://brickseek.com/walmart-inventory-checker? -o html72764.html
# curl --data "sku=625412161&zip=92803" https://brickseek.com/walmart-inventory-checker? -o html92803.html
# curl --data "sku=625412161&zip=94509" https://brickseek.com/walmart-inventory-checker? -o html94509.html
# curl --data "sku=625412161&zip=93380" https://brickseek.com/walmart-inventory-checker? -o html93380.html
# curl --data "sku=625412161&zip=91706" https://brickseek.com/walmart-inventory-checker? -o html91706.html
# curl --data "sku=625412161&zip=90706" https://brickseek.com/walmart-inventory-checker? -o html90706.html
# curl --data "sku=625412161&zip=90201" https://brickseek.com/walmart-inventory-checker? -o html90201.html
# curl --data "sku=625412161&zip=94704" https://brickseek.com/walmart-inventory-checker? -o html94704.html
# curl --data "sku=625412161&zip=91505" https://brickseek.com/walmart-inventory-checker? -o html91505.html
# curl --data "sku=625412161&zip=91710" https://brickseek.com/walmart-inventory-checker? -o html91710.html
# curl --data "sku=625412161&zip=91709" https://brickseek.com/walmart-inventory-checker? -o html91709.html
# curl --data "sku=625412161&zip=91910" https://brickseek.com/walmart-inventory-checker? -o html91910.html
# curl --data "sku=625412161&zip=94520" https://brickseek.com/walmart-inventory-checker? -o html94520.html
# curl --data "sku=625412161&zip=91718" https://brickseek.com/walmart-inventory-checker? -o html91718.html
# curl --data "sku=625412161&zip=92628" https://brickseek.com/walmart-inventory-checker? -o html92628.html
# curl --data "sku=625412161&zip=94015" https://brickseek.com/walmart-inventory-checker? -o html94015.html
# curl --data "sku=625412161&zip=90241" https://brickseek.com/walmart-inventory-checker? -o html90241.html
# curl --data "sku=625412161&zip=91734" https://brickseek.com/walmart-inventory-checker? -o html91734.html
# curl --data "sku=625412161&zip=95624" https://brickseek.com/walmart-inventory-checker? -o html95624.html
# curl --data "sku=625412161&zip=92025" https://brickseek.com/walmart-inventory-checker? -o html92025.html
# curl --data "sku=625412161&zip=94533" https://brickseek.com/walmart-inventory-checker? -o html94533.html

# %%
from __future__ import division, unicode_literals 
import codecs
from bs4 import BeautifulSoup
import os

filepath = os.path.join("html83708.html")
with open(filepath, encoding='utf-8') as file:
    html = file.read()

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/><script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(3),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){function r(){if(!E++){var e=x.info=NREUM.info,n=l.getElementsByTagName("script")[0];if(setTimeout(s.abort,3e4),!(e&&e.licenseKey&&e.applicationID&&n))return s.abort();c ...
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <script> dataLayer = []; </script>
# <script>
# 	dataLayer.push({
# 		"user_logged_in": 0,
# 		"user_level": 0,
# 		"user_id": 0,
# 	});
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MV827XZ');</script>
# <script>
# 			(function(html, CSS){
# 				html.className = html.className.replace(/\bno-js\b/,'js');
# 			})(document.documentElement, CSS);
# 		</script>
# <script src="//try.abtasty.com/bed7fd6a7f04a37cd8543226887f84aa.js" type="text/javascript"></script>
# <title>Yankee Candle Vanilla Cupcake – Large Classic Jar Candle – Walmart Inventory Checker – BrickSeek</title>
# <link href="//brickseek.com" rel="dns-prefetch">
# <link href="//use.typekit.net" rel="dns-prefetch"/>
# <link href="//cdn1.brickseek.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://brickseek.com/wp-content/plugins/memberpress/css/ui/theme.css?ver=1.3.24" id="mp-theme-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://brickseek.com/wp-includes/css/dist/block-library/style.min.css?ver=5.2.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://brickseek.com/wp-content/plugins/stackable-ultimate-gutenberg-blocks-premium/dist/frontend_blocks.css?ver=1.15.1" id="ugb-style-css-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="ugb-style-css-inline-css" type="text/css">
# :root {
# 			--content-width: 600px;
# 		}
# </style>
# <link href="https://brickseek.com/wp-content/plugins/stackable-ultimate-gutenberg-blocks-premium/dist/frontend_blocks__premium_only.css?ver=1.15.1" id="ugb-style-css-premium-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://use.typekit.net/vfn5fxi.css?ver=3.1.1" id="bs-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://cdn1.brickseek.com/fontawesome/css/all.css?ver=3.1.1" id="bs-icons-fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://brickseek.com/wp-content/themes/brickseek/css/theme.css?ver=3.1.1" id="bs-theme-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://brickseek.com/wp-content/plugins/stackable-ultimate-gutenberg-blocks-premium/dist/frontend_blocks.js?ver=1.15.1" type="text/javascript"></script>
# <script src="https://brickseek.com/wp-content/plugins/stackable-ultimate-gutenberg-blocks-premium/dist/frontend_blocks__premium_only.js?ver=1.15.1" type="text/javascript"></script>
# <script src="https://brickseek.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script src="https://brickseek.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script src="https://brickseek.com/wp-content/themes/brickseek/js/quagga.min.js?ver=3.1.1" type="text/javascript"></script>
# <script src="https://brickseek.com/wp-content/themes/brickseek/js/modernizr.min.js?ver=3.1.1" type="text/javascript"></script>
# <link href="https://brickseek.com/wp-json/" rel="https://api.w.org/"/>
# <meta content="WordPress 5.2.2" name="generator">
# <link href="https://brickseek.com/?p=9648" rel="shortlink"/>
# <link href="https://brickseek.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fbrickseek.com%2Fwalmart-inventory-checker%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://brickseek.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fbrickseek.com%2Fwalmart-inventory-checker%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://cdn1.brickseek.com/images/brickseek-favicon.png?ver=3.1.1" rel="shortcut icon" type="image/x-icon"/>
# <script data-cfasync="false" id="bs-freestar-snippet" type="text/javascript">
# 		var freestar = freestar || {};
# 		freestar.hitTime = Date.now();
# 		freestar.queue = freestar.queue || [];
# 		freestar.config = freestar.config || {};
# 		freestar.debug = window.location.search.indexOf('fsdebug') === -1 ? false : true;
#
# 		// Tag IDs set here, must match Tags served in the Body for proper setup
# 		freestar.config.enabled_slots = ["brickseek_728x90_300x250_320x50_ATF","brickseek_728x90_300x250_320x50_BTF","brickseek_300x600_320x250_160x600_Right","brickseek_300x250_Right2","brickseek_728x90_300x250_320x50_inlist_1","brickseek_728x90_300x250_320x50_inlist_2"];
#
# 		!function(a,b){var c=b.getElementsByTagName("script")[0],d=b.createElement("script"),e="https://a.pub.network/brickseek-com";e+=freestar.debug?"/qa/pubfig.min.js":"/pubfig.min.js",d.async=!0,d.src=e,c.parentNode.insertBefore(d,c)}(window,document);
# 		</script>
# <script id="bs-profitwell-snippet">
# 		(function(i,s,o,g,r,a,m){i['ProfitWellObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m);
# 		})(window,document,'script','https://dna8twue3dlxq.cloudfront.net/js/profitwell.js','profitwell');
# 		profitwell('auth_token', 'd62c460eb96a27a6dc5664ae30a09fe1'); // Your unique Profitwell public API token
# 			</script>
# <meta content="BrickSeek" property="og:site_name"><meta content="website" property="og:type"><meta content="https://brickseek.com/walmart-inventory-checker?" property="og:url"/><meta content="Yankee Candle Vanilla Cupcake - Large Classic Jar Candle - Walmart Inventory Checker - BrickSeek" property="og:title"/><meta content="Items are priced differently from store-to-store. Use BrickSeek's Inventory Checkers to search your item and see its current, real-time stock count and pricing at stores near you." property="og:description"/><meta content="https://i5.walmartimages.com/asr/6796d5e2-16c9-48ea-8b05-1ccebee3f10f_1.8a36dc964e104e2bef36fd166a2991ef.jpeg" property="og:image"/> <style id="wp-custom-css" type="text/css">
# 			/* [BUG FIX] */
# .aligncenter.wp-block-embed iframe {
# 	margin: 0 auto;
# }
#
# /* [BUG FIX] This hides the currently experimental filter for available near you products */
# .filters__section.products-filters__available-locally.filters__available-locally {
# 	display: none !important;
# }
#
# /* [BUG FIX] Hides the sidebar promo for premium users */
# body.user-level-premium #bs-cta-sidebar-promo {
# 	display: none;
# }		</style>
# </meta></meta></meta></link></head>
# <body class="page-template-default page page-id-9648 color-scheme-default sidebar-enabled banner-active header-ad-enabled footer-ad-enabled sidebar_1-ad-enabled sidebar_2-ad-enabled main_content_1-ad-enabled main_content_2-ad-enabled inventory-checker">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MV827XZ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="site" id="page">
# <div aria-hidden="true" class="header-body-cover"></div>
# <header class="header section" id="masthead" role="banner">
# <div class="wrap">
# <div class="header__branding">
# <a href="/">
# <span class="header__title">
# <img alt="BrickSeek" class="header__title-symbol" src="https://cdn1.brickseek.com/images/header-logo-icon-transparent.png?ver=3.1.1"/>
# <span class="header__title-brick">Brick</span>
# <span class="header__title-seek">Seek</span>
# </span>
# </a>
# </div> <nav class="header__menu" role="navigation">
# <div class="header__menu-item header__top-level-item header__dropdown-parent">
# <a href="/deals/">Deals</a>
# <div class="header__dropdown header__dropdown--wide">
# <a class="header__dropdown-item" href="/deals/">
# All Trending Deals </a>
# <a class="header__dropdown-item" href="/deals/online/">
# Trending Online Deals </a>
# <a class="header__dropdown-item" href="/deals/in-store/">
# Trending In-Store Deals </a>
# <span class="header__dropdown-title">Featured Categories</span>
# <div class="header__dropdown-list-split">
# <a class="header__dropdown-item" href="/deals/electronics/">
# Electronics </a>
# <a class="header__dropdown-item" href="/deals/toys/">
# Toys &amp; Games </a>
# <a class="header__dropdown-item" href="/deals/home-goods/">
# Home Goods </a>
# <a class="header__dropdown-item" href="/deals/baby/">
# Baby </a>
# <a class="header__dropdown-item" href="/deals/sporting-goods/">
# Sporting Goods </a>
# <a class="header__dropdown-item" href="/deals/tools/">
# Tools </a>
# </div>
# </div>
# </div>
# <div class="header__menu-item header__top-level-item header__dropdown-parent">
# <span>Inventory Checkers</span>
# <div class="header__dropdown">
# <div class="header__dropdown-store-list">
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/walmart-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="walmart" class="" src="https://cdn1.brickseek.com/logos/walmart-logo.png"/></span>
# <span class="header__dropdown-item-store-name">Walmart</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/target-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="target" class="" src="https://cdn1.brickseek.com/logos/target-logo.png"/></span>
# <span class="header__dropdown-item-store-name">Target</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/lowes-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="lowes" class="" src="https://cdn1.brickseek.com/logos/lowes-logo.png"/></span>
# <span class="header__dropdown-item-store-name">Lowes</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/office-depot-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="office-depot" class="" src="https://cdn1.brickseek.com/logos/office-depot-logo.png"/></span>
# <span class="header__dropdown-item-store-name">Office Depot</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/macys-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="macys" class="" src="https://cdn1.brickseek.com/logos/macys-logo.png"/></span>
# <span class="header__dropdown-item-store-name">Macy's</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/home-depot-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="home-depot" class="" src="https://cdn1.brickseek.com/logos/home-depot-logo.png"/></span>
# <span class="header__dropdown-item-store-name">Home Depot</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/cvs-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="cvs" class="" src="https://cdn1.brickseek.com/logos/cvs-logo.png"/></span>
# <span class="header__dropdown-item-store-name">CVS</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/staples-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="staples" class="" src="https://cdn1.brickseek.com/logos/staples-logo.png"/></span>
# <span class="header__dropdown-item-store-name">Staples</span>
# </a>
# <a class="header__dropdown-item header__dropdown-item--store-logo" href="/bjs-inventory-checker/">
# <span class="header__dropdown-item-store-image"><img alt="bjs" class="" src="https://cdn1.brickseek.com/logos/bjs-logo.png"/></span>
# <span class="header__dropdown-item-store-name">BJ's</span>
# </a>
# </div>
# </div>
# </div>
# <div class="header__menu-item header__top-level-item header__dropdown-parent">
# <span>Members Area</span>
# <div class="header__dropdown">
# <span class="header__dropdown-title">Premium Members</span>
# <div class="header__dropdown-group">
# <span class="header__dropdown-group-title">
# <span class="far fa-lock-alt"></span> Markdowns by Store </span>
# <div class="header__dropdown-group-items header__dropdown-group-items--wide">
# <p><strong class="header__dropdown-promo-title">Markdowns by Store</strong></p>
# <p>Choose any store near you and view its recently detected markdowns in one convenient place. It's that easy.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mambs-0919">Upgrade to Premium for Access</a>
# </p></div>
# </div>
# <div class="header__dropdown-group">
# <span class="header__dropdown-group-title">
# <span class="far fa-lock-alt"></span> Today's Markdowns </span>
# <div class="header__dropdown-group-items header__dropdown-group-items--wide">
# <p><strong class="header__dropdown-promo-title">Today's Markdowns</strong></p>
# <p>New day, new markdowns. Today's Markdowns shows you exactly which items are most commonly being marked down across the nation day to day.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-matm-0919">Upgrade to Premium for Access</a>
# </p></div>
# </div>
# <div class="header__dropdown-group">
# <span class="header__dropdown-group-title">
# <span class="far fa-lock-alt"></span> Popular Searches </span>
# <div class="header__dropdown-group-items header__dropdown-group-items--wide">
# <p><strong class="header__dropdown-promo-title">Popular Searches</strong></p>
# <p>With Popular Searches you can view the most popular items on BrickSeek. If an item is listed here, then it's there for a reason. Search these items in your area to find out why!</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-maps-0919">Upgrade to Premium for Access</a>
# </p></div>
# </div>
# <div class="header__dropdown-group">
# <span class="header__dropdown-group-title">
# <span class="far fa-lock-alt"></span> BrickSeek Rewards </span>
# <div class="header__dropdown-group-items header__dropdown-group-items--wide">
# <p><strong class="header__dropdown-promo-title">BrickSeek Rewards</strong></p>
# <p>Thousands of exclusive offers covering a range of popular categories including travel, dining, wellness, and entertainment.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mabr-0919">Upgrade to Premium for Access</a>
# </p></div>
# </div>
# <span class="header__dropdown-title">Extreme Members</span>
# <div class="header__dropdown-group">
# <span class="header__dropdown-group-title">
# <span class="far fa-lock-alt"></span> Local Markdown Feed </span>
# <div class="header__dropdown-group-items header__dropdown-group-items--wide">
# <p><strong class="header__dropdown-promo-title">Local Markdown Feed</strong></p>
# <p>Local Markdown Feed is an all-in-one page for viewing detected markdowns across all stores near you. Included with each listed markdown is a secondary expandable list of the nearby stores which that markdown was detected in. It's every deal hunters dream.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-malmf-0919">Upgrade to Extreme for Access</a>
# </p></div>
# </div>
# <div class="header__dropdown-group">
# <span class="header__dropdown-group-title">
# <span class="far fa-lock-alt"></span> Online Markdown Feed </span>
# <div class="header__dropdown-group-items header__dropdown-group-items--wide">
# <p><strong class="header__dropdown-promo-title">Online Markdown Feed</strong></p>
# <p>Prefer to do your deal hunting online? Online Markdown Feed is the most extensive list of recent online markdowns across the web.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-maomf-0919">Upgrade to Extreme for Access</a>
# </p></div>
# </div>
# </div>
# </div>
# <div class="header__menu-item header__top-level-item">
# <a href="/blog/">Blog</a>
# </div>
# <div class="header__menu-item header__top-level-item">
# <a href="https://talk.brickseek.com/" rel="noopener noreferrer" target="_blank">Community</a>
# </div>
# </nav> <div class="header__search">
# <div class="header__search-container">
# <div class="header__search-bar-container">
# <form action="/products/" class="header__search-bar">
# <div class="header__search-method">
# <select class="header__search-method-select" id="header-search-method">
# <option selected="selected" value="products">Products</option>
# <option value="deals">Deals</option>
# <option value="rewards">Rewards</option>
# </select>
# </div>
# <input autocomplete="off" class="header__search-query" data-current-search="" id="header-search-query" name="search" type="text" value=""/>
# <button class="header__search-submit" type="submit"><span class="far fa-search"></span><span class="screen-reader-text">Search</span></button>
# <span class="header__search-done"><span class="screen-reader-text">Done</span></span>
# </form>
# </div>
# <div class="header__search-panel">
# <div class="header__search-panel-content">
# </div>
# </div>
# </div>
# </div> <div class="header__launch-actions">
# <div class="header__launch-account header__top-level-item header__dropdown-parent">
# <span class="header__launch-account-icon">
# <span class="header__launch-account-icon-head"></span>
# <span class="header__launch-account-icon-body"></span>
# </span>
# <span class="screen-reader-text header__launch-account-text">Account</span>
# <div class="header__dropdown header__dropdown--wide">
# <div class="header__user-portal">
# <div class="header__dropdown-item header__user-portal-login">
# <a href="/login/?redirect_to=https://brickseek.com/walmart-inventory-checker?">Login</a>
# </div>
# <div class="header__dropdown-item header__user-portal-sign-up">
# <a href="/sign-up?src=s-h-adsu-0919">Sign Up</a>
# </div>
# </div>
# <span class="header__dropdown-title">Welcome to BrickSeek</span>
# <a class="header__dropdown-item" href="/features/">
# Features Overview </a>
# <a class="header__dropdown-item" href="https://help.brickseek.com">
# Help Center </a>
# </div>
# </div> <div class="header__launch-mobile-menu">
# <span class="header__launch-mobile-menu-icon">
# <span class="header__launch-mobile-menu-icon-line header__launch-mobile-menu-icon-line--1"></span>
# <span class="header__launch-mobile-menu-icon-line header__launch-mobile-menu-icon-line--2"></span>
# <span class="header__launch-mobile-menu-icon-line header__launch-mobile-menu-icon-line--3"></span>
# </span>
# <span class="screen-reader-text header__launch-mobile-menu-text">Menu</span>
# </div> </div>
# </div>
# <nav class="header__mobile-menu" role="navigation">
# <div class="header__mobile-menu-sections">
# <div class="header__mobile-menu-section">
# <div class="header__user-portal">
# <div class="header__mobile-menu-item header__user-portal-login">
# <a href="/login/?redirect_to=https://brickseek.com/walmart-inventory-checker?">Login</a>
# </div>
# <div class="header__mobile-menu-item header__user-portal-sign-up">
# <a href="/sign-up?src=s-mm-adsu-0919">Sign Up</a>
# </div>
# </div>
# </div>
# <div class="header__mobile-menu-section">
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="deals">
# <span>Deals</span>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="inventory-checkers">
# <span>Inventory Checkers</span>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/blog/">Blog</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="https://talk.brickseek.com/" rel="noopener noreferrer" target="_blank">Community</a>
# </div>
# </div>
# <div class="header__mobile-menu-section">
# <div class="header__mobile-menu-section-title">Premium Members</div>
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="markdowns-by-store">
# <span>
# <span class="far fa-lock-alt"></span>
# Markdowns by Store </span>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="todays-markdowns">
# <span>
# <span class="far fa-lock-alt"></span>
# Today's Markdowns </span>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="popular-searches">
# <span>
# <span class="far fa-lock-alt"></span>
# Popular Searches </span>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="brickseek-rewards">
# <span>
# <span class="far fa-lock-alt"></span>
# BrickSeek Rewards </span>
# </div>
# </div>
# <div class="header__mobile-menu-section">
# <div class="header__mobile-menu-section-title">Extreme Members</div>
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="local-markdown-feed">
# <span>
# <span class="far fa-lock-alt"></span>
# Local Markdown Feed </span>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item-parent" data-open-mobile-menu-panel="online-markdown-feed">
# <span>
# <span class="far fa-lock-alt"></span>
# Online Markdown Feed </span>
# </div>
# </div>
# </div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="deals">
# <div class="header__mobile-menu-panel-header">
# Deals <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <div class="header__mobile-menu-section">
# <div class="header__mobile-menu-item">
# <a href="/deals/">All Trending Deals</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/deals/online/">Trending Online Deals</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/deals/in-store/">Trending In-Store Deals</a>
# </div>
# </div>
# <div class="header__mobile-menu-section">
# <div class="header__mobile-menu-section-title">Featured Categories</div>
# <div class="header__mobile-menu-list-split">
# <div class="header__mobile-menu-item">
# <a href="/deals/electronics/">Electronics</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/deals/toys/">Toys</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/deals/home-goods/">Home Goods</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/deals/baby/">Baby</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/deals/sporting-goods/">Sporting Goods</a>
# </div>
# <div class="header__mobile-menu-item">
# <a href="/deals/tools/">Tools</a>
# </div>
# </div>
# </div>
# </div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="inventory-checkers">
# <div class="header__mobile-menu-panel-header">
# Inventory Checkers <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <div class="header__mobile-menu-store-list">
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/walmart-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="walmart" class="" src="https://cdn1.brickseek.com/logos/walmart-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">Walmart</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/target-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="target" class="" src="https://cdn1.brickseek.com/logos/target-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">Target</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/lowes-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="lowes" class="" src="https://cdn1.brickseek.com/logos/lowes-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">Lowes</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/office-depot-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="office-depot" class="" src="https://cdn1.brickseek.com/logos/office-depot-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">Office Depot</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/macys-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="macys" class="" src="https://cdn1.brickseek.com/logos/macys-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">Macy's</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/home-depot-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="home-depot" class="" src="https://cdn1.brickseek.com/logos/home-depot-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">Home Depot</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/cvs-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="cvs" class="" src="https://cdn1.brickseek.com/logos/cvs-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">CVS</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/staples-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="staples" class="" src="https://cdn1.brickseek.com/logos/staples-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">Staples</span>
# </a>
# </div>
# <div class="header__mobile-menu-item header__mobile-menu-item--store-logo">
# <a href="/bjs-inventory-checker/">
# <span class="header__mobile-menu-item-store-image"><img alt="bjs" class="" src="https://cdn1.brickseek.com/logos/bjs-logo.png"/></span>
# <span class="header__mobile-menu-item-store-name">BJ's</span>
# </a>
# </div>
# </div>
# </div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="popular-searches">
# <div class="header__mobile-menu-panel-header">
# <span class="far fa-lock-alt"></span>
# Popular Searches <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <p>With Popular Searches you can view the most popular items on BrickSeek. If an item is listed here, then it's there for a reason. Search these items in your area to find out why!</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mmmaps-0919">Upgrade to Premium for Access</a>
# </p></div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="todays-markdowns">
# <div class="header__mobile-menu-panel-header">
# <span class="far fa-lock-alt"></span>
# Today's Markdowns <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <p>New day, new markdowns. Today's Markdowns shows you exactly which items are most commonly being marked down across the nation day to day.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mmmatm-0919">Upgrade to Premium for Access</a>
# </p></div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="markdowns-by-store">
# <div class="header__mobile-menu-panel-header">
# <span class="far fa-lock-alt"></span>
# Markdowns by Store <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <p>Choose any store near you and view its recently detected markdowns in one convenient place. It's that easy.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mmmambs-0919">Upgrade to Premium for Access</a>
# </p></div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="local-markdown-feed">
# <div class="header__mobile-menu-panel-header">
# <span class="far fa-lock-alt"></span>
# Local Markdown Feed <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <p>Local Markdown Feed is an all-in-one page for viewing detected markdowns across all stores near you. Included with each listed markdown is a secondary expandable list of the nearby stores which that markdown was detected in. It's every deal hunters dream.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mmmalmf-0919">Upgrade to Extreme for Access</a>
# </p></div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="brickseek-rewards">
# <div class="header__mobile-menu-panel-header">
# <span class="far fa-lock-alt"></span>
# BrickSeek Rewards <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <p>Thousands of exclusive offers covering a range of popular categories including travel, dining, wellness, and entertainment.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mmmabr-0919">Upgrade to Premium for Access</a>
# </p></div>
# <div class="header__mobile-menu-panel" data-mobile-menu-panel-id="online-markdown-feed">
# <div class="header__mobile-menu-panel-header">
# <span class="far fa-lock-alt"></span>
# Online Markdown Feed <div class="header__mobile-menu-panel-done">Back</div>
# </div>
# <p>Prefer to do your deal hunting online? Online Markdown Feed is the most extensive list of recent online markdowns across the web.</p>
# <p><a class="header__dropdown-promo-button" href="/sign-up?src=s-h-mmmaomf-0919">Upgrade to Premium for Access</a>
# </p></div>
# </nav> </header>
# <div class="ad ad--location-header" data-ad-slot="brickseek_728x90_300x250_320x50_ATF">
# <div class="ad__slot">
# <div align="center" id="brickseek_728x90_300x250_320x50_ATF">
# <script data-cfasync="false" type="text/javascript">
#     freestar.queue.push(function () { googletag.display('brickseek_728x90_300x250_320x50_ATF'); });
# </script>
# </div> </div>
# </div>
# <div class="body">
# <div class="section banner">
# <div class="wrap">
# <div class="banner__content">
# <h1 class="banner__title">
# <span class="banner__title-text">Walmart Inventory Checker</span>
# </h1>
# </div>
# </div>
# </div>
# <div class="section section--sidebar section--sidebar-right">
# <div class="wrap">
# <main class="main section__main" id="main" role="main">
# <div class="ajax-target" data-ajax-target="main">
# <form autocomplete="off" class="form form--vertical-spacing-bottom inventory-checker-form" method="post">
# <p class="form__info">
# Need help finding a SKU?<br/> Try our <span class="inventory-checker-form__launch-sku-finder js-link">SKU finder</span>.
# </p>
# <div class="grid inventory-checker-form__grid inventory-checker-form__grid--upc">
# <div class="grid__item inventory-checker-form__method">
# <div class="grid__item-content">
# <label>Search by</label>
# <div class="form-radio-wrap grid" data-columns="2">
# <input checked="checked" id="inventory-checker-form-method-sku" name="method" type="radio" value="sku"/>
# <label class="form-radio-wrap__item grid__item" for="inventory-checker-form-method-sku">
# <span class="form-radio-wrap__item-text">SKU</span>
# </label>
# <input id="inventory-checker-form-method-upc" name="method" type="radio" value="upc"/>
# <label class="form-radio-wrap__item grid__item" for="inventory-checker-form-method-upc">
# <span class="form-radio-wrap__item-text">UPC</span>
# </label>
# </div>
# </div>
# </div>
# <div class="grid__item inventory-checker-form__sku">
# <div class="grid__item-content">
# <label class="form__label" for="inventory-checker-form-sku">SKU</label>
# <input class="" id="inventory-checker-form-sku" inputmode="numeric" name="sku" spellcheck="false" type="text" value="600104275"/>
# </div>
# </div>
# <div class="grid__item inventory-checker-form__upc" style="display:none;">
# <div class="grid__item-content">
# <label class="form__label" for="inventory-checker-form-upc">UPC</label>
# <input id="inventory-checker-form-upc" inputmode="numeric" name="upc" spellcheck="false" type="text" value=""/>
# </div>
# </div>
# <div class="grid__item inventory-checker-form__zip">
# <div class="grid__item-content">
# <label class="form__label" for="inventory-checker-form-zip">Zip Code</label>
# <div class="location-control">
# <input autocomplete="off" class="location-control__input" id="inventory-checker-form-zip" inputmode="numeric" name="zip" spellcheck="false" type="text" value="83708"/>
# <span class="location-control__activate" title="Use my current location"></span>
# <span class="location-control__active-message">My Location</span>
# <input class="location-control__checkbox" id="inventory-checker-form-location-control-active" name="use_location" type="checkbox" value="1"/>
# </div>
# </div>
# </div>
# <div class="grid__item inventory-checker-form__sort">
# <div class="grid__item-content">
# <label class="form__label" for="inventory-checker-form-sort">Sort by</label>
# <div class="select-wrap">
# <select id="inventory-checker-form-sort" name="sort">
# <option selected="selected" value="recommended">
# Recommended </option>
# <option value="distance">
# Distance </option>
# <option value="price">
# Price </option>
# <option value="quan">
# Quantity </option>
# </select>
# </div>
# </div>
# </div>
# <div class="grid__item inventory-checker-form__submit grid__item--align-content-end">
# <div class="grid__item-content">
# <button type="submit"><span>Check Inventory</span></button>
# </div>
# </div>
# </div>
# </form>
# <div class="item-overview item-overview--vertical-spacing-bottom">
# <div class="item-overview__image">
# <div class="item-overview__image-wrap">
# <img alt="Yankee Candle Vanilla Cupcake - Large Classic Jar Candle" src="https://i5.walmartimages.com/asr/6796d5e2-16c9-48ea-8b05-1ccebee3f10f_1.8a36dc964e104e2bef36fd166a2991ef.jpeg"/>
# </div>
# </div>
# <div class="item-overview__info">
# <h2 class="section-title">Yankee Candle Vanilla Cupcake - Large Classic Jar Candle</h2>
# <div class="item-overview__section">
# <div class="item-overview__meta">
# <div class="item-overview__meta-item">
# <strong>MSRP:</strong> <span class="price-formatted price-formatted--style-normal">$19.87</span> </div>
# <div class="item-overview__meta-item">
# <strong>SKU:</strong> 600104275 </div>
# <div class="item-overview__meta-item">
# <strong>UPC:</strong> 886860684556 <a class="barcode-link" href="http://barcode.live?upc=886860684556" rel="noopener noreferrer" target="_blank"><span>View barcode</span></a> </div>
# </div>
# </div>
# <div class="item-overview__section">
# <div class="item-overview__actions">
# <a class="item-overview__actions-item" href="/p/yankee-candle-vanilla-cupcake/4233894">
# <span class="item-overview__actions-item-icon"><span class="far fa-camera-alt"></span></span>
# <span>BrickSeek Snapshot</span>
# </a>
# <a class="item-overview__actions-item" href="http://linksynergy.walmart.com/fs-bin/click?id=PxE*ot9VSWM&amp;offerid=223073.7200&amp;type=14&amp;catid=8&amp;subid=0&amp;hid=7200&amp;tmpid=1082&amp;RD_PARM1=https://www.walmart.com/ip/600104275" target="_blank">
# <span class="item-overview__actions-item-icon"><span class="far fa-warehouse"></span></span>
# <span>View on Walmart</span>
# </a>
# <span class="item-overview__actions-item inventory-checker-add-local-alert" data-sku="600104275" data-store-type="3" data-zip="83708">
# <span class="item-overview__actions-item-icon"><span class="far fa-bells"></span></span>
# <span>Local Alerts</span>
# </span>
# </div>
# </div>
# <div class="item-overview__section item-overview__section--border-top">
# <h4 class="item-overview__section-title">Online Offers</h4>
# <div class="item-overview__online-listings">
# <a class="item-overview__online-listing" href="http://linksynergy.walmart.com/fs-bin/click?id=PxE*ot9VSWM&amp;offerid=223073.7200&amp;type=14&amp;catid=8&amp;subid=0&amp;hid=7200&amp;tmpid=1082&amp;RD_PARM1=https://www.walmart.com/ip/600104275" target="_blank">
# <span class="item-overview__online-listing-price"><span class="price-formatted price-formatted--style-normal">$19.87</span></span>
# <span class="item-overview__online-listing-condition">
# New </span>
# <span class="item-overview__online-listing-store">Walmart</span>
# </a>
# </div>
# <div class="item-overview__online-listing-updated">
# Updated EST <span class="js-link launch-amazon-disclaimer-modal">more info</span>.
# BrickSeek may receive a small commission for items purchased through links found on our site. </div>
# </div>
# <div class="item-overview__section item-overview__section--border-top">
# <h4 class="item-overview__section-title">Share</h4>
# <div class="item-overview__share">
# <div class="item-overview__share-networks">
# <a class="item-overview__share-networks-item item-overview__share-networks-item--facebook" href="https://www.facebook.com/sharer.php?u=https://brickseek.com/walmart-inventory-checker?sku=600104275" rel="noopener noreferrer" target="_blank">
# <span class="screen-reader-text">Share this page on Facebook</span>
# </a>
# <a class="item-overview__share-networks-item item-overview__share-networks-item--twitter" href="https://twitter.com/share?url=https://brickseek.com/walmart-inventory-checker?sku=600104275&amp;text=Yankee%20Candle%20Vanilla%20Cupcake%20-%20Large%20Classic%20Jar%20Candle%20-%20Walmart%20Inventory%20Checker%20-%20BrickSeek" rel="noopener noreferrer" target="_blank">
# <span class="screen-reader-text">Share this page on Twitter</span>
# </a>
# </div>
# <div class="item-overview__share-link">
# <label class="item-overview__share-link-label" for="item-overview-share-link"><span class="screen-reader-text">Sharable link</span></label>
# <input class="item-overview__share-link-input" data-sku="600104275" id="item-overview-share-link" type="text" value="https://brickseek.com/walmart-inventory-checker?sku=600104275"/>
# <span class="item-overview__share-link-copy" data-clipboard-target="#item-overview-share-link"><span class="screen-reader-text">Copy link</span></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="local-inventory-disclaimer">
# <div class="local-inventory-disclaimer__content">
# <h3 class="local-inventory-disclaimer__title">About Local Inventory Results:</h3>
# <ol>
# <li>BrickSeek is a third party application. Retail stores will not honor inventory or pricing discrepancies between their store and BrickSeek.</li>
# <li>Theft, loss, and other circumstances at the store level can cause inventory inaccuracies.</li>
# <li>Please do not use BrickSeek as a point of reference when talking to retailers. </li>
# <li>Be respectful and happy deal seeking!</li>
# </ol>
# <span class="js-link local-inventory-disclaimer__confirm">I understand, don't show this message again</span>
# </div>
# </div>
# <div class="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3">
# <div class="table__header">
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# Store </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# Availability </div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# Price </div>
# </div>
# </div>
# </div>
# <div class="table__body">
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #3739 </strong>
# <address class="address">
# 5875 E Franklin Rd<br/>Nampa ID 83687 <div class="address__below">
# (14.6 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=5875+E+Franklin+Rd+Nampa+ID+83687" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=5875+E+Franklin+Rd+Nampa+ID+83687">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 6</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--featured">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">5</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">00</span></span> <span class="table__cell-price-discount">75% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2861 </strong>
# <address class="address">
# 7319 W State St<br/>Boise ID 83714 <div class="address__below">
# (5.1 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=7319+W+State+St+Boise+ID+83714" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=7319+W+State+St+Boise+ID+83714">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 14</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2508 </strong>
# <address class="address">
# 8300 W Overland Rd<br/>Boise ID 83709 <div class="address__below">
# (3.5 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=8300+W+Overland+Rd+Boise+ID+83709" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=8300+W+Overland+Rd+Boise+ID+83709">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 2</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="ad ad--location-main_content_1" data-ad-slot="brickseek_728x90_300x250_320x50_inlist_1">
# <div class="ad__slot">
# <div align="center" id="brickseek_728x90_300x250_320x50_inlist_1">
# <script data-cfasync="false" type="text/javascript">
#     freestar.queue.push(function () { googletag.display('brickseek_728x90_300x250_320x50_inlist_1'); });
# </script>
# </div> </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2862 </strong>
# <address class="address">
# 4051 E Fairview Ave<br/>Meridian ID 83642 <div class="address__below">
# (6.2 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=4051+E+Fairview+Ave+Meridian+ID+83642" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=4051+E+Fairview+Ave+Meridian+ID+83642">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 2</span><br>
# </br></div>
# </div>
# ...
# 					<div class="grid__item-content">
# 						<button type="submit"><span>Save</span></button>
# 					</div>
# 				</div>
# 			</div>
# 			<input type="hidden" name="store_type" id="set-target-price-form-store-type" value="3" />
# 		</form>
# 		<div class="set-target-price-delete">
# 			<span class="js-link set-target-price-delete__button">Delete saved target price</span>
# 		</div>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-amazon-disclaimer" type="text/html">
# 			<div class="modal amazon-disclaimer-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">About Amazon.com Results</h4>
# 		<span class="modal__close">Close</span>
# 	</div>
# 	<div class="modal__body">
# 		<p>Product prices and availability are accurate as of the date/time indicated and are subject to change. Any price and availability information displayed on Amazon.com at the time of purchase will apply to the purchase of this product.</p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-limited-stock-disclaimer" type="text/html">
# 			<div class="modal limited-stock-disclaimer-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">About Limited Stock Results</h4>
# 		<span class="modal__close">Close</span>
# 	</div>
# 	<div class="modal__body">
# 		<div class="limited-stock-disclaimer-option" data-store-type="1">
# 			<p>Based on information from the retailer, it appears one may be available; however, this may be the display model and unavailable for sale. For products in high demand, Target may indicate Limited Stock due to low supply.</p>
# 		</div>
# 		<div class="limited-stock-disclaimer-option">
# 			<p>Based on information from the retailer, it appears one may be available; however, this may be the display model and unavailable for sale.</p>
# 		</div>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-view-store-history" type="text/html">
# 			<div class="modal view-store-history-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Store History</h4>
# 		<span class="modal__close">Close</span>
# 	</div>
# 	<div class="modal__body">
# 		<div class="modal__table view-store-history-modal-table">
# 			<div class="modal__table-header">
# 				<div class="modal__table-row">
# 					<div class="modal__table-cell table__cell--align-left view-store-history-modal-table__entered">
# 						Entered (EST)					</div>
# 					<div class="modal__table-cell view-store-history-modal-table__quantity">
# 						Quantity					</div>
# 					<div class="modal__table-cell view-store-history-modal-table__price">
# 						Price					</div>
# 				</div>
# 			</div>
# 			<div class="modal__table-body"></div>
# 		</div>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-marketplace-info" type="text/html">
# </script>
# <script id="js-template-modal-login-to-like-deal" type="text/html">
# 			<div class="modal login-to-like-deal-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Log in to Like Deals</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<p>You must be <a href="/login/?redirect_to=https://brickseek.com/walmart-inventory-checker?">logged in</a> to like a deal.</p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-account-add-tags" type="text/html">
# 			<div class="modal add-tags-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Add new Tags</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<form class="modal__form add-tags-form">
# 			<div class="grid add-tags-form__grid">
# 				<div class="grid__item add-tags-form__tags">
# 					<div class="grid__item-content">
# 						<label class="form__label screen-reader-text" for="add-tags-form-tags">New Tags to Add</label>
# 						<input type="text" name="tags" id="add-tags-form-tags" />
# 					</div>
# 				</div>
# 				<div class="grid__item add-tags-form__submit grid__item--align-content-end">
# 					<div class="grid__item-content">
# 						<button type="submit"><span>Add Tags</span></button>
# 					</div>
# 				</div>
# 			</div>
# 		</form>
# 			</div>
# </div>		</script>
# <script id="js-template-modal-account-confirm-delete-selected" type="text/html">
# 			<div class="modal account-confirm-delete-selected-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Delete Selected Items</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<p>Are you sure you wish to delete (<span class="table__selection-count-placeholder"></span>) selected items? All selected items will be removed from this list. This action cannot be undone.</p>
# 		<p><span class="js-link js-link--delete modal__trigger-confirm">Yes, delete selected items</span></p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-account-confirm-submit" type="text/html">
# 			<div class="modal account-confirm-submit-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Save Changes</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<p>Are you sure you wish to save (<span class="table__modified-count-placeholder"></span>) changes? This action cannot be undone.</p>
# 		<p><span class="js-link js-link--confirm modal__trigger-confirm">Yes, save all changes</span></p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-account-confirm-reset-my-stores" type="text/html">
# 			<div class="modal account-confirm-reset-my-stores-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Your &quot;My Stores&quot; Settings Will be Lost</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<p>You are about to change your profiles zip code, if you continue then your current settings for &quot;My Stores&quot; will be reset to the default setting based on your newly entered zip code. This action cannot be undone. Are you sure you wish to continue?</p>
# 		<p><span class="js-link js-link--delete modal__trigger-confirm">Yes, save all changes and reset my stores selection</span></p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-account-confirm-restore-defaults" type="text/html">
# 			<div class="modal account-confirm-restore-defaults-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Restore Default Settings</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<p>Are you sure you wish to restore default settings? This action cannot be undone.</p>
# 		<p><span class="js-link js-link--delete modal__trigger-confirm">Yes, restore default settings</span></p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-product-super-check-inventory" type="text/html">
# </script>
# <script id="js-template-modal-product-super-pricing-records" type="text/html">
# </script>
# <script id="js-template-modal-product-super-enter-zip" type="text/html">
# 			<div class="modal change-zip-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Show Offers Near You</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<form method="post" action="/p//1307853#in-store-offers" class="modal__form change-zip-form" autocomplete="off">
# 			<div class="grid change-zip-form__grid">
# 				<div class="grid__item change-zip-form__zip">
# 					<div class="grid__item-content">
# 						<label class="form__label screen-reader-text" for="product-super-enter-zip-modal-zip">Zip Code</label>
# 						<div class="location-control ">
# 							<input type="text"  inputmode="numeric" name="zip" placeholder="Your zip code" spellcheck="false" autocomplete="off" class="location-control__input" id="product-super-enter-zip-modal-zip" value="83708" />
# 							<span class="location-control__activate" title="Use my current location"></span>
# 							<span class="location-control__active-message">My Location</span>
# 		                    <input type="checkbox" class="location-control__checkbox" id="change-zip-form-location-control-active" name="use_location" value="1"  />
# 						</div>
# 					</div>
# 				</div>
# 				<div class="grid__item change-zip-form__submit grid__item--align-content-end">
# 					<div class="grid__item-content">
# 						<button type="submit"><span>Show Offers</span></button>
# 					</div>
# 				</div>
# 			</div>
# 		</form>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-request-bulk-search" type="text/html">
# </script>
# <script id="js-template-modal-change-zip" type="text/html">
# 			<div class="modal change-zip-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Show Results Near a Different Zip</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<form class="modal__form change-zip-form" autocomplete="off">
# 			<div class="grid change-zip-form__grid">
# 				<div class="grid__item change-zip-form__zip">
# 					<div class="grid__item-content">
# 						<label class="form__label screen-reader-text" for="change-zip-form-zip">Zip Code</label>
# 						<div class="location-control ">
# 							<input type="text"  inputmode="numeric" name="zip" spellcheck="false" autocomplete="off" class="location-control__input" id="change-zip-form-zip" value="83708" />
# 							<span class="location-control__activate" title="Use my current location"></span>
# 							<span class="location-control__active-message">My Location</span>
# 		                    <input type="checkbox" class="location-control__checkbox" id="change-zip-form-location-control-active" name="use_location" value="1"  />
# 						</div>
# 					</div>
# 				</div>
# 				<div class="grid__item change-zip-form__submit grid__item--align-content-end">
# 					<div class="grid__item-content">
# 						<button type="submit"><span>Submit</span></button>
# 					</div>
# 				</div>
# 			</div>
# 					</form>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-site-announcement" type="text/html">
# </script>
# <script id="js-template-modal-scanner" type="text/html">
# 			<div class="modal scanner-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Barcode Scanner</h4>
# 		<span class="modal__close">Close</span>
# 	</div>
# 	<div class="modal__body">
# 		<div id="scanner" class="scanner"></div>
# 		<div class="scanner-modal__crosshair">
# 			<div class="scanner-modal__crosshair-corner-top-left"></div>
# 			<div class="scanner-modal__crosshair-corner-top-right"></div>
# 			<div class="scanner-modal__crosshair-corner-bottom-left"></div>
# 			<div class="scanner-modal__crosshair-corner-bottom-right"></div>
# 		</div>
# 		<div class="scanner-modal__crosshair-cover-top"></div>
# 		<div class="scanner-modal__crosshair-cover-right"></div>
# 		<div class="scanner-modal__crosshair-cover-bottom"></div>
# 		<div class="scanner-modal__crosshair-cover-left"></div>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-about-map-view" type="text/html">
# 			<div class="modal about-map-view-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">About Map View</h4>
# 		<span class="modal__close">Close</span>
# 	</div>
# 	<div class="modal__body">
# 		<p><strong>Utilizing Controls</strong></p>
# 		<ul>
# 			<li><u>Detail</u> - Quickly zoom in for a more detailed look at the search results on the map. Click any item to view additional information.</li>
# 			<li><u>Overview</u> - Zoom out and reposition the map for a birds eye view of all search results in your area.</li>
# 			<li><u>My Location</u> - Displays your current location on the map. Click again to center the map to your current location.</li>
# 		</ul>
# 		<p><strong>More Information</strong></p>
# 		<p>You can disable the map from your account settings page <a href="/account/?action=home" target="_blank" rel="noopener noreferrer">here</a>.</p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-reusable-template" type="text/html">
# 			<div class="modal modal-reusable">
# 	<div class="modal__header">
# 		<h4 class="modal__title"></h4>
# 		<span class="modal__close">Close</span>
# 	</div>
# 	<div class="modal__body"></div>
# </div>		</script>
# <script id="js-template-modal-rewards-welcome" type="text/html">
# 			<div class="modal modal--headerless rewards-welcome-modal">
# 	<div class="modal__body">
# 		<h2 class="section-title">Congratulations, You're all Set!</h2>
# 		<p>You have been enrolled in the BrickSeek Rewards program and now have access to a huge catalogue of exclusive local and online savings.</p>
# 		<a class="button" href="/rewards/"><span>Start Exploring Deals <span class="far fa-chevron-right"></span></span></a>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-rewards-confirm-redeem" type="text/html">
# 			<div class="modal rewards-confirm-redeem-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">Redeem Offer</h4>
# 		<span class="modal__close">Cancel</span>
# 	</div>
# 	<div class="modal__body">
# 		<p data-show-when="plural">This offer can be redeemed <strong data-remaining></strong> more times.</p>
# 		<p data-show-when="one-remaining">This offer can only be redeemed <strong>1</strong> more time.</p>
# 		<p data-show-when="only-one"><strong>This offer can only be redeemed once.</strong></p>
# 		<p>Are you sure you wish to redeem it now?</p>
# 		<p><span class="js-link js-link--confirm modal__trigger-confirm">Yes, redeem this offer now</span></p>
# 	</div>
# </div>		</script>
# <script id="js-template-modal-rewards-redemptions-used" type="text/html">
# 			<div class="modal rewards-redemptions-used-modal">
# 	<div class="modal__header">
# 		<h4 class="modal__title">No Redemptions Remaining</h4>
# 		<span class="modal__close">Close</span>
# 	</div>
# 	<div class="modal__body">
# 		<p>You have reached your redemption quota for this offer, it can not be redeemed again at this time.</p>
# 	</div>
# </div>		</script>
# <script type="text/javascript">
#         jQuery(document).ready(function ($) {
#             //$( document ).ajaxStart(function() {
#             //});
#
#
#             for (var i = 0; i < document.forms.length; ++i) {
#                 var form = document.forms[i];
# 				if ($(form).attr("method") != "get") { $(form).append('<input type="hidden" name="_LkNiouJZhOFzHR" value="H4I_a9ZkfdCDPoj" />'); }
# if ($(form).attr("method") != "get") { $(form).append('<input type="hidden" name="YKJmh-NQXRuD" value="O[HDXTUysdu9" />'); }
# if ($(form).attr("method") != "get") { $(form).append('<input type="hidden" name="EmWpdPiAGnc" value="ybBQluhGrT5" />'); }
# if ($(form).attr("method") != "get") { $(form).append('<input type="hidden" name="DsdaYLSwTt" value="bWTpV]1ym3" />'); }
#             }
#
#
#             $(document).on('submit', 'form', function () {
# 				if ($(this).attr("method") != "get") { $(this).append('<input type="hidden" name="_LkNiouJZhOFzHR" value="H4I_a9ZkfdCDPoj" />'); }
# if ($(this).attr("method") != "get") { $(this).append('<input type="hidden" name="YKJmh-NQXRuD" value="O[HDXTUysdu9" />'); }
# if ($(this).attr("method") != "get") { $(this).append('<input type="hidden" name="EmWpdPiAGnc" value="ybBQluhGrT5" />'); }
# if ($(this).attr("method") != "get") { $(this).append('<input type="hidden" name="DsdaYLSwTt" value="bWTpV]1ym3" />'); }
#                 return true;
#             });
#
#
#             jQuery.ajaxSetup({
#                 beforeSend: function (e, data) {
#
#                     //console.log(Object.getOwnPropertyNames(data).sort());
#                     //console.log(data.type);
#
#                     if (data.type !== 'POST') return;
#
#                     if (typeof data.data === 'object' && data.data !== null) {
# 						data.data.append("_LkNiouJZhOFzHR", "H4I_a9ZkfdCDPoj");
# data.data.append("YKJmh-NQXRuD", "O[HDXTUysdu9");
# data.data.append("EmWpdPiAGnc", "ybBQluhGrT5");
# data.data.append("DsdaYLSwTt", "bWTpV]1ym3");
#                     }
#                     else {
#                         data.data =  data.data + '&_LkNiouJZhOFzHR=H4I_a9ZkfdCDPoj&YKJmh-NQXRuD=O[HDXTUysdu9&EmWpdPiAGnc=ybBQluhGrT5&DsdaYLSwTt=bWTpV]1ym3';
#                     }
#                 }
#             });
#
#         });
# 	</script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"3283ea3d17","applicationID":"282536246","transactionName":"NV0EYBMDWUBQU0QIWwwXJ1cVC1hdHlleBVEa","queueTime":0,"applicationTime":2656,"atts":"GRoHFlsZSk4=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
#item-overview__meta-item

s=soup.find_all('div', class_='item-overview__meta-item')[1].text
import re

result = re.search('\nSKU:(.*)', s)
print(result.group(1))
# Out:
#  600104275

# %%
all_data = soup.find('div', class_="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3")
# .find('span', class_="table__cell-price-discount")
print(all_data)
# Out:
# <div class="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3">
# <div class="table__header">
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# Store </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# Availability </div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# Price </div>
# </div>
# </div>
# </div>
# <div class="table__body">
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #3739 </strong>
# <address class="address">
# 5875 E Franklin Rd<br/>Nampa ID 83687 <div class="address__below">
# (14.6 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=5875+E+Franklin+Rd+Nampa+ID+83687" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=5875+E+Franklin+Rd+Nampa+ID+83687">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 6</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--featured">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">5</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">00</span></span> <span class="table__cell-price-discount">75% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2861 </strong>
# <address class="address">
# 7319 W State St<br/>Boise ID 83714 <div class="address__below">
# (5.1 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=7319+W+State+St+Boise+ID+83714" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=7319+W+State+St+Boise+ID+83714">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 14</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2508 </strong>
# <address class="address">
# 8300 W Overland Rd<br/>Boise ID 83709 <div class="address__below">
# (3.5 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=8300+W+Overland+Rd+Boise+ID+83709" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=8300+W+Overland+Rd+Boise+ID+83709">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 2</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="ad ad--location-main_content_1" data-ad-slot="brickseek_728x90_300x250_320x50_inlist_1">
# <div class="ad__slot">
# <div align="center" id="brickseek_728x90_300x250_320x50_inlist_1">
# <script data-cfasync="false" type="text/javascript">
#     freestar.queue.push(function () { googletag.display('brickseek_728x90_300x250_320x50_inlist_1'); });
# </script>
# </div> </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2862 </strong>
# <address class="address">
# 4051 E Fairview Ave<br/>Meridian ID 83642 <div class="address__below">
# (6.2 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=4051+E+Fairview+Ave+Meridian+ID+83642" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=4051+E+Fairview+Ave+Meridian+ID+83642">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 2</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart #3093 </strong>
# <address class="address">
# 795 West Overland Road<br/>Meridian ID 83642 <div class="address__below">
# (9.2 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=795+West+Overland+Road+Meridian+ID+83642" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=795+West+Overland+Road+Meridian+ID+83642">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 3</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #5841 </strong>
# <address class="address">
# 5001 N. Ten Mile Rd.<br/>Meridian ID 83646 <div class="address__below">
# (11.1 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=5001+N.+Ten+Mile+Rd.+Meridian+ID+83646" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=5001+N.+Ten+Mile+Rd.+Meridian+ID+83646">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 3</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2781 </strong>
# <address class="address">
# 2100 12Th Ave Rd<br/>Nampa ID 83686 <div class="address__below">
# (18.1 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=2100+12Th+Ave+Rd+Nampa+ID+83686" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=2100+12Th+Ave+Rd+Nampa+ID+83686">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 19</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="ad ad--location-main_content_2" data-ad-slot="brickseek_728x90_300x250_320x50_inlist_2">
# <div class="ad__slot">
# <div align="center" id="brickseek_728x90_300x250_320x50_inlist_2">
# <script data-cfasync="false" type="text/javascript">
#     freestar.queue.push(function () { googletag.display('brickseek_728x90_300x250_320x50_inlist_2'); });
# </script>
# </div> </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2780 </strong>
# <address class="address">
# 5108 Cleveland Blvd<br/>Caldwell ID 83607 <div class="address__below">
# (21.4 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=5108+Cleveland+Blvd+Caldwell+ID+83607" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=5108+Cleveland+Blvd+Caldwell+ID+83607">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 11</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #2782 </strong>
# <address class="address">
# 2745 American Legion Blvd<br/>Mountain Home ID 83647 <div class="address__below">
# (43.1 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=2745+American+Legion+Blvd+Mountain+Home+ID+83647" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=2745+American+Legion+Blvd+Mountain+Home+ID+83647">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 11</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--featured">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">5</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">00</span></span> <span class="table__cell-price-discount">75% off</span>
# </div>
# </div>
# </div>
# </div>
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #1951 </strong>
# <address class="address">
# 1775 E Idaho Ave<br/>Ontario OR 97914 <div class="address__below">
# (45.9 Miles Away) </div>
# <div class="address__links">
# <a class="address__link" href="https://maps.google.com/maps?q=1775+E+Idaho+Ave+Ontario+OR+97914" rel="noopener noreferrer" target="_blank">Google Maps</a>
# <span class="address__link-separator"></span>
# <a class="address__link" href="http://maps.apple.com/?address=1775+E+Idaho+Ave+Ontario+OR+97914">Apple Maps</a>
# </div>
# </address>
# </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# <div class="availability-status-indicator availability-status-indicator--stock-2 availability-status-indicator--style-label" data-store-type="3"><span class="availability-status-indicator__text">In Stock</span></div> <span class="table__cell-quantity">Quantity: 18</span><br>
# </br></div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# <div class="table__cell-price table__cell-price--muted">
# <span class="price-formatted price-formatted--style-display"><span class="price-formatted__currency">$</span><span class="price-formatted__dollars">16</span><span class="price-formatted__decimal">.</span><span class="price-formatted__cents">88</span></span> <span class="table__cell-price-discount">15% off</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
price_value=all_data.find_all('span', class_='table__cell-price-discount')
print(len(price_value))
# Out:
# 10

# %%
discount=[]

for item in price_value:
    discount.append(item.text)
print(discount)
# Out:
# ['75% off', '15% off', '15% off', '15% off', '15% off', '15% off', '15% off', '15% off', '75% off', '15% off']

# %%
address_ex = [item.text.split('\n')[1] for item in all_data.find_all('address', class_='address') ]
print(address_ex)
# Out:
# ['5875 E Franklin RdNampa ID 83687 ', '7319 W State StBoise ID 83714 ', '8300 W Overland RdBoise ID 83709 ', '4051 E Fairview AveMeridian ID 83642 ', '795 West Overland RoadMeridian ID 83642 ', '5001 N. Ten Mile Rd.Meridian ID 83646 ', '2100 12Th Ave RdNampa ID 83686 ', '5108 Cleveland BlvdCaldwell ID 83607 ', '2745 American Legion BlvdMountain Home ID 83647 ', '1775 E Idaho AveOntario OR 97914 ']

# %%
quantity=[ indi.text for indi in all_data.find_all('span', class_='availability-status-indicator__text') ]
print(quantity)
# Out:
# ['In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock']

# %%
pages = [ {"price-off": discount[i], "store-address" : address_ex[i], "quantity": quantity[i] }  for i in range(len(discount))]

# %%
for page in pages:
    print(page)
# Out:
# {'price-off': '75% off', 'store-address': '5875 E Franklin RdNampa ID 83687 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '7319 W State StBoise ID 83714 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '8300 W Overland RdBoise ID 83709 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '4051 E Fairview AveMeridian ID 83642 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '795 West Overland RoadMeridian ID 83642 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '5001 N. Ten Mile Rd.Meridian ID 83646 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '2100 12Th Ave RdNampa ID 83686 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '5108 Cleveland BlvdCaldwell ID 83607 ', 'quantity': 'In Stock'}
# {'price-off': '75% off', 'store-address': '2745 American Legion BlvdMountain Home ID 83647 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '1775 E Idaho AveOntario OR 97914 ', 'quantity': 'In Stock'}

# %%
pages_data=pd.DataFrame.from_dict(pages)
pages_data.head(10)
# Out:
#   price-off  quantity                                     store-address
# 0   75% off  In Stock                 5875 E Franklin RdNampa ID 83687
# 1   15% off  In Stock                    7319 W State StBoise ID 83714
# 2   15% off  In Stock                 8300 W Overland RdBoise ID 83709
# 3   15% off  In Stock             4051 E Fairview AveMeridian ID 83642
# 4   15% off  In Stock          795 West Overland RoadMeridian ID 83642
# 5   15% off  In Stock            5001 N. Ten Mile Rd.Meridian ID 83646
# 6   15% off  In Stock                   2100 12Th Ave RdNampa ID 83686
# 7   15% off  In Stock             5108 Cleveland BlvdCaldwell ID 83607
# 8   75% off  In Stock  2745 American Legion BlvdMountain Home ID 83647
# 9   15% off  In Stock                 1775 E Idaho AveOntario OR 97914

# %%
pages_data=pages_data.dropna()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-b874ae966b29> in <module>
#       1
# ----> 2 pages_data=pages_data.drop(['index'], axis=1)
#
# ~\Anaconda3\envs\pythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\envs\pythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~\Anaconda3\envs\pythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# ~\Anaconda3\envs\pythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
pages_data.to_sql('market_scraped_data', engine, index=False, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in pages_data})

# %%
pd.read_sql_query('select * from market_scraped_data', con=engine).head(20)
# Out:
#     index price-off       quantity        sku  \
# 0       0   76% off       In Stock  625412161
# 1       1   76% off       In Stock  625412161
# 2       2   76% off       In Stock  625412161
# 3       3   76% off       In Stock  625412161
# 4       4   76% off  Limited Stock  625412161
# 5       5   76% off       In Stock  625412161
# 6       6   76% off  Limited Stock  625412161
# 7       7   76% off   Out of Stock  625412161
# 8       8   76% off   Out of Stock  625412161
# 9       9   53% off   Out of Stock  625412161
# 10     10    6% off   Out of Stock  625412161
# 11     11   76% off       In Stock  625412161
# 12     12   76% off       In Stock  625412161
# 13     13   76% off  Limited Stock  625412161
# 14     14   53% off       In Stock  625412161
# 15     15   53% off  Limited Stock  625412161
# 16     16   53% off   Out of Stock  625412161
# 17     17   76% off       In Stock  625412161
# 18     18   76% off  Limited Stock  625412161
# 19     19   76% off  Limited Stock  625412161
#
#                                   store-address zip-code:
# 0                 209 Lakeshore PkwyHomewood AL     35209
# 1                   9248 Parkway EBirmingham AL     35206
# 2                      890 Odum RdGardendale AL     35071
# 3                 5335 Highway 280Birmingham AL     35242
# 4               2780 John Hawkins PkwyHoover AL     35244
# 5                    8551 Whitfield AveLeeds AL     35094
# 6       630 Colonial Promenade PkwyAlabaster AL     35007
# 7                     2181 Pelham PkwyPelham AL     35124
# 8   5919 Trussville Crossings PkwyBirmingham AL     35235
# 9                   16077 Highway 280Chelsea AL     35043
# 10               2473 Hackworth RdBirmingham AL     35214
# 11                      8580 Hwy 72 WMadison AL     35758
# 12           3031 Memorial Pkwy SwHuntsville AL     35801
# 13                   5601 Highway 157Cullman AL     35058
# 14                  8650 Madison BlvdMadison AL     35758
# 15                6140A Univ DriveHuntsville AL     35806
# 16         330 Sutton Rd SeOwens Cross Roads AL     35763
# 17              101 E I65 Service Rd SMobile AL     36606
# 18              1095 Industrial PkwySaraland AL     36571
# 19                685 Schillinger Rd SMobile AL     36695

# %%
# remember to delete .html files
import os
for item in zips:
    s.remove('html'+ item +'.html')

# %%
import glob
path = '../html_pages_new_sku/*.html'   
files = glob.glob(path)
for file in files:
    with open(file, encoding='utf-8') as file:
          read_html_content = file.read()
    soup = BeautifulSoup(read_html_content, 'html.parser')
    all_data = soup.find('div', class_="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3")
            # .find('span', class_="table__cell-price-discount")
    price_value=all_data.find_all('span', class_='table__cell-price-discount')
            #print(price_value)  
    discount=[ item.text for item in price_value ]
            #print("divya", discount)
    address_ex = [item.text.split('\n')[1] for item in all_data.find_all('address', class_='address') ]
            #print("address", address_ex)
    quantity=[ indi.text for indi in all_data.find_all('span', class_='availability-status-indicator__text') ]
            #print("quantity", quantity)
    s=soup.find_all('div', class_='item-overview__meta-item')[1].text
    import re
    sku_search = re.search('\nSKU:(.*)', s)
    sku=sku_search.group(1)

    pages_dict = [ {"sku": sku, "zip-code:":  address_ex[i].split()[-1], "price-off": discount[i], \
                            "store-address" : ' '.join(address_ex[i].split()[:-1]), \
                            "quantity": quantity[i] } for i in range(len(discount)) ]
            #for page in pages_dict:
            #    print(page) 
    print(pages_dict)
# Out:
# [{'sku': ' 600104275 ', 'zip-code:': '33155', 'price-off': '75% off', 'store-address': '8400 Coral WayMiami FL', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '
A', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95621', 'price-off': '15% off', 'store-address': '7010 Auburn BlvdCitrus Heights CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95842', 'price-off': '15% off', 'store-address': '5821 Antelope RdSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95677', 'price-off': '15% off', 'store-address': '5454 Crossings DriveRocklin CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95630', 'price-off': '15% off', 'store-address': '1018 Riley StFolsom CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95843', 'price-off': '15% off', 'store-address': '7901 Watt AveAntelope CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95605', 'price-off': '15% off', 'store-address': '755 Riverpoint CtWest Sacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95823', 'price-off': '15% off', 'store-address': '6051 Florin RdSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95829', 'price-off': '15% off', 'store-address': '8915 Gerber RoadSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95670', 'price-off': '75% off', 'store-address': '10655 Folsom BlvdRancho Cordova CA', 'quantity': 'Out of Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95662', 'price-off': '55% off', 'store-address': '8961 Greenback LnOrangevale CA', 'quantity': 'Out of Stock'}]
# [{'sku': ' 600104275 ', 'zip-code:': '95834', 'price-off': '75% off', 'store-address': '3661 Truxel RdSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95660', 'price-off': '75% off', 'store-address': '4675 Watt AvenueNorth Highlands CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95605', 'price-off': '15% off', 'store-address': '755 Riverpoint CtWest Sacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95823', 'price-off': '15% off', 'store-address': '6051 Florin RdSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95842', 'price-off': '15% off', 'store-address': '5821 Antelope RdSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95843', 'price-off': '15% off', 'store-address': '7901 Watt AveAntelope CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95832', 'price-off': '15% off', 'store-address': '8270 Delta Shores CircleSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95829', 'price-off': '15% off', 'store-address': '8915 Gerber RoadSacramento CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95621', 'price-off': '15% off', 'store-address': '7010 Auburn BlvdCitrus Heights CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95758', 'price-off': '15% off', 'store-address': '8465 Elk Grove BlvdElk Grove CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95661', 'price-off': '15% off', 'store-address': '1400 Lead Hill BlvdRoseville CA', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95670', 'price-off': '75% off', 'store-address': '10655 Folsom BlvdRancho Cordova CA', 'quantity': 'Out of Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95662', 'price-off': '55% off', 'store-address': '8961 Greenback LnOrangevale CA', 'quantity': 'Out of Stock'}, {'sku': ' 600104275 ', 'zip-code:': '95757', 'price-off': '55% off', 'store-address': '10075 Bruceville RdElk Grove CA', 'quantity': 'Out of Stock'}]
# [{'sku': ' 600104275 ', 'zip-code:': '99515', 'price-off': '2% off', 'store-address': '8900 Old Seward HwyAnchorage AK', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '99504', 'price-off': '2% off', 'store-address': '7405 Debarr RoadAnchorage AK', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '99577', 'price-off': '2% off', 'store-address': '18600 Eagle River RdEagle River AK', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '99654', 'price-off': '75% off', 'store-address': '1350 S Seward Meridian PkwyWasilla AK', 'quantity': 'In Stock'}, {'sku': ' 600104275 ', 'zip-code:': '99503', 'price-off': '75% off', 'store-address': '3101 A StAnchorage AK', 'quantity': 'Out of Stock'}]

# %%
market_scraped_data = 'market_scraped_data'
connection = engine.raw_connection()
cursor = connection.cursor()
command = "DROP TABLE IF EXISTS {};".format(market_scraped_data)
cursor.execute(command)
connection.commit()
cursor.close()

# %%
pages_dict

pages_data_df = pd.DataFrame.from_dict(page_dict_list)
pages_data_df=pages_data_df.dropna()
pages_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-5fb1e16aa2da> in <module>
# ----> 1 pages_data_df = pd.DataFrame.from_dict(page_dict_list)
#       2 pages_data_df=pages_data_df.dropna()
#       3 pages_data_df.head(10)
#
# NameError: name 'page_dict_list' is not defined
