# %%
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy
import os

# %%
csv_file = "postgres_zip_city.csv"
customer_data_df = pd.read_csv(csv_file)
#customer_data_df.head()

# %%
customer_data_df= customer_data_df.reset_index()

# %%
rds_connection_string = "bedlgjelgbrcba:62edbf5e39edf1ea129a38a5766d7354579374a6db487103a421c76fd47d78c3@ec2-184-73-232-93.compute-1.amazonaws.com:5432/dd4i4baf4sjibo"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# []

# %%
city_zip_data = 'market_scraped_data'

# %%
# drop city_zip_data if it exist already
connection = engine.raw_connection()
cursor = connection.cursor()
command = "DROP TABLE IF EXISTS {};".format(city_zip_data)
cursor.execute(command)
connection.commit()
cursor.close()

# %%
engine.table_names()
# Out:
# ['test', 'zip_vs_coordinates']

# %%
# create 'city_zip_data' table and fill up data 
customer_data_df.to_sql('city_zip_data', engine, dtype={col_name: sqlalchemy.types.VARCHAR for col_name in customer_data_df})

# %%
customer_data_df=customer_data_df.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1aeba1ce7a7e> in <module>
# ----> 1 customer_data_df=customer_data_df.reset_index(drop=True, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
print(customer_data_df)
# Out:
# None

# %%
customer_data_df.to_sql('market_scraped_data', engine, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in customer_data_df})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-afcb10544fc4> in <module>
# ----> 1 customer_data_df.to_sql('market_scraped_data', engine, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in customer_data_df})
#
# AttributeError: 'NoneType' object has no attribute 'to_sql'

# %%
pd.read_sql_query('select * from market_scraped_data', con=engine).head()
# Out:
#    index price-off       quantity        sku                    store-address  \
# 0      0   76% off       In Stock  625412161    209 Lakeshore PkwyHomewood AL
# 1      1   76% off       In Stock  625412161      9248 Parkway EBirmingham AL
# 2      2   76% off       In Stock  625412161         890 Odum RdGardendale AL
# 3      3   76% off       In Stock  625412161    5335 Highway 280Birmingham AL
# 4      4   76% off  Limited Stock  625412161  2780 John Hawkins PkwyHoover AL
#
#   zip-code:
# 0     35209
# 1     35206
# 2     35071
# 3     35242
# 4     35244

# %%
import sqlalchemy

from sqlalchemy import Column, Integer, String, Float

from sqlalchemy.orm import Session

from sqlalchemy.ext.automap import automap_base

from sqlalchemy import create_engine, inspect

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['zip_vs_coordinates', 'city_zip_data', 'market_scraped_data']

# %%
columns = inspector.get_columns('city_zip_data')
print(columns[3]['name'])
# Out:
# zip

# %%
import re
zips = [re.sub("\'|\,|\(|\)", "", str(item)) for item in engine.execute('SELECT zip FROM city_zip_data LIMIT 40').fetchall()]
zips
# Out:
# ['35203',
#  '35813',
#  '36601',
#  '36119',
#  '99599',
#  '85225',
#  '86001',
#  '85296',
#  '85302',
#  '85201',
#  '85381',
#  '85026',
#  '85251',
#  '85282',
#  '85726',
#  '85364',
#  '72764',
#  '72903',
#  '72202',
#  '72764',
#  '92803',
#  '94509',
#  '93380',
#  '91706',
#  '90706',
#  '90201',
#  '94704',
#  '91505',
#  '91710',
#  '91709',
#  '91910',
#  '94520',
#  '91718',
#  '92628',
#  '94015',
#  '90241',
#  '91734',
#  '95624',
#  '92025',
#  '94533']

# %%
# !!! important the sku must be set as variable  !!!
sku = 329264833
zips=[19901,19805,20090,34203,33909,33990,32931,33075,32114,33310,33908,32601,33010,33022,32203,32025,33152,33023,32802,33024,32514,33060,34952,33730,32301,33630,34293,30608,30304,30901,31908,30044,31204,31402,96820,83708,83401,83301,60505,61701,60607,60436,62959,60540,61601]
for item in zips:
    command= 'curl --data ' + '"sku=' + str(sku) + '&zip=' + str(item) + '" https://brickseek.com/walmart-inventory-checker? -o html'+ str(item)+'.html'
    output=os.system(command)
    print(command)
# Out:
# curl --data "sku=329264833&zip=19901" https://brickseek.com/walmart-inventory-checker? -o html19901.html
# curl --data "sku=329264833&zip=19805" https://brickseek.com/walmart-inventory-checker? -o html19805.html
# curl --data "sku=329264833&zip=20090" https://brickseek.com/walmart-inventory-checker? -o html20090.html
# curl --data "sku=329264833&zip=34203" https://brickseek.com/walmart-inventory-checker? -o html34203.html
# curl --data "sku=329264833&zip=33909" https://brickseek.com/walmart-inventory-checker? -o html33909.html
# curl --data "sku=329264833&zip=33990" https://brickseek.com/walmart-inventory-checker? -o html33990.html
# curl --data "sku=329264833&zip=32931" https://brickseek.com/walmart-inventory-checker? -o html32931.html
# curl --data "sku=329264833&zip=33075" https://brickseek.com/walmart-inventory-checker? -o html33075.html
# curl --data "sku=329264833&zip=32114" https://brickseek.com/walmart-inventory-checker? -o html32114.html
# ...

# %%
from __future__ import division, unicode_literals 
import codecs
from bs4 import BeautifulSoup
import os

filepath = os.path.join("html83708.html")
with open(filepath, encoding='utf-8') as file:
    html = file.read()

# %%
from __future__ import division, unicode_literals 
import codecs
from bs4 import BeautifulSoup
import os

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# ...

# %%
#item-overview__meta-item

s=soup.find_all('div', class_='item-overview__meta-item')[1].text
import re

result = re.search('\nSKU:(.*)', s)
print(result.group(1))
# Out:
#  600104275

# %%
all_data = soup.find('div', class_="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3")
# .find('span', class_="table__cell-price-discount")
print(all_data)
# Out:
# <div class="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3">
# <div class="table__header">
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# Store </div>
# </div>
# <div class="table__cell inventory-checker-table__availability">
# <div class="table__cell-content">
# Availability </div>
# </div>
# <div class="table__cell inventory-checker-table__price">
# <div class="table__cell-content">
# Price </div>
# </div>
# </div>
# </div>
# <div class="table__body">
# <div class="table__row">
# <div class="table__cell table__cell--align-left inventory-checker-table__store">
# <div class="table__cell-content">
# <strong class="address-location-name">
# Walmart Supercenter #3739 </strong>
# <address class="address">
# 5875 E Franklin Rd<br/>Nampa ID 83687 <div class="address__below">
# (14.6 Miles Away) </div>
# ...

# %%
price_value=all_data.find_all('span', class_='table__cell-price-discount')
print(len(price_value))
# Out:
# 10

# %%
discount=[]

for item in price_value:
    discount.append(item.text)
print(discount)
# Out:
# ['75% off', '15% off', '15% off', '15% off', '15% off', '15% off', '15% off', '15% off', '75% off', '15% off']

# %%
address_ex = [item.text.split('\n')[1] for item in all_data.find_all('address', class_='address') ]
print(address_ex)
# Out:
# ['5875 E Franklin RdNampa ID 83687 ', '7319 W State StBoise ID 83714 ', '8300 W Overland RdBoise ID 83709 ', '4051 E Fairview AveMeridian ID 83642 ', '795 West Overland RoadMeridian ID 83642 ', '5001 N. Ten Mile Rd.Meridian ID 83646 ', '2100 12Th Ave RdNampa ID 83686 ', '5108 Cleveland BlvdCaldwell ID 83607 ', '2745 American Legion BlvdMountain Home ID 83647 ', '1775 E Idaho AveOntario OR 97914 ']

# %%
quantity=[ indi.text for indi in all_data.find_all('span', class_='availability-status-indicator__text') ]
print(quantity)
# Out:
# ['In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock', 'In Stock']

# %%
pages = [ {"price-off": discount[i], "store-address" : address_ex[i], "quantity": quantity[i] }  for i in range(len(discount))]

# %%
for page in pages:
    print(page)
# Out:
# {'price-off': '75% off', 'store-address': '5875 E Franklin RdNampa ID 83687 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '7319 W State StBoise ID 83714 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '8300 W Overland RdBoise ID 83709 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '4051 E Fairview AveMeridian ID 83642 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '795 West Overland RoadMeridian ID 83642 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '5001 N. Ten Mile Rd.Meridian ID 83646 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '2100 12Th Ave RdNampa ID 83686 ', 'quantity': 'In Stock'}
# {'price-off': '15% off', 'store-address': '5108 Cleveland BlvdCaldwell ID 83607 ', 'quantity': 'In Stock'}
# {'price-off': '75% off', 'store-address': '2745 American Legion BlvdMountain Home ID 83647 ', 'quantity': 'In Stock'}
# ...

# %%
pages_data=pd.DataFrame.from_dict(pages)
pages_data.head(10)
# Out:
#   price-off  quantity                                     store-address
# 0   75% off  In Stock                 5875 E Franklin RdNampa ID 83687
# 1   15% off  In Stock                    7319 W State StBoise ID 83714
# 2   15% off  In Stock                 8300 W Overland RdBoise ID 83709
# 3   15% off  In Stock             4051 E Fairview AveMeridian ID 83642
# 4   15% off  In Stock          795 West Overland RoadMeridian ID 83642
# 5   15% off  In Stock            5001 N. Ten Mile Rd.Meridian ID 83646
# 6   15% off  In Stock                   2100 12Th Ave RdNampa ID 83686
# 7   15% off  In Stock             5108 Cleveland BlvdCaldwell ID 83607
# 8   75% off  In Stock  2745 American Legion BlvdMountain Home ID 83647
# 9   15% off  In Stock                 1775 E Idaho AveOntario OR 97914

# %%
pages_data=pages_data.dropna()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-b874ae966b29> in <module>
#       1
# ----> 2 pages_data=pages_data.drop(['index'], axis=1)
#
# ~\Anaconda3\envs\pythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\envs\pythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
pages_data.to_sql('market_scraped_data', engine, index=False, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in pages_data})

# %%
pd.read_sql_query('select * from market_scraped_data', con=engine).head(20)
# Out:
#     index price-off       quantity        sku  \
# 0       0   76% off       In Stock  625412161
# 1       1   76% off       In Stock  625412161
# 2       2   76% off       In Stock  625412161
# 3       3   76% off       In Stock  625412161
# 4       4   76% off  Limited Stock  625412161
# 5       5   76% off       In Stock  625412161
# 6       6   76% off  Limited Stock  625412161
# 7       7   76% off   Out of Stock  625412161
# 8       8   76% off   Out of Stock  625412161
# 9       9   53% off   Out of Stock  625412161
# 10     10    6% off   Out of Stock  625412161
# 11     11   76% off       In Stock  625412161
# 12     12   76% off       In Stock  625412161
# 13     13   76% off  Limited Stock  625412161
# 14     14   53% off       In Stock  625412161
# 15     15   53% off  Limited Stock  625412161
# 16     16   53% off   Out of Stock  625412161
# 17     17   76% off       In Stock  625412161
# 18     18   76% off  Limited Stock  625412161
# ...

# %%
# remember to delete .html files
import os
for item in zips:
    s.remove('html'+ item +'.html')

# %%
import glob
path = '../Python_Modules/target/target/*.html'
files = glob.glob(path)
for file in files:
    print(file)
# Out:
# ../Python_Modules/target/target\html19805.html
# ../Python_Modules/target/target\html19901.html
# ../Python_Modules/target/target\html20090.html
# ../Python_Modules/target/target\html32025.html
# ../Python_Modules/target/target\html32931.html
# ../Python_Modules/target/target\html33075.html
# ../Python_Modules/target/target\html33909.html
# ../Python_Modules/target/target\html33990.html
# ../Python_Modules/target/target\html34203.html
# ../Python_Modules/target/target\html35203.html
# ../Python_Modules/target/target\html35813.html
# ../Python_Modules/target/target\html36119.html
# ../Python_Modules/target/target\html36601.html
# ../Python_Modules/target/target\html72764.html
# ../Python_Modules/target/target\html80004.html
# ../Python_Modules/target/target\html80017.html
# ../Python_Modules/target/target\html80030.html
# ../Python_Modules/target/target\html80202.html
# ../Python_Modules/target/target\html80221.html
# ../Python_Modules/target/target\html80525.html
# ...

# %%
import sqlalchemy
from bs4 import BeautifulSoup
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine, inspect
#import connectDB
import numpy
import re
import os 
import codecs
import pandas as pd

# %%
import glob
path = '../../html/Scrape_wmt/scrape_yankee/html_to_db/*.html'


files = glob.glob(path)
# try:
google_query = []
for file in files:
    with open(file, encoding='utf-8') as file:
            read_html_content = file.read()
    soup = BeautifulSoup(read_html_content, 'html.parser')
    all_data = soup.find('div', class_="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3")
            # .find('span', class_="table__cell-price-discount")
    price_value=all_data.find_all('span', class_='table__cell-price-discount')
            #print(price_value)  
    discount=[ item.text for item in price_value ]
    google_link = all_data.find_all('a', class_="address__link")[0]['href']
    gmaps_query = google_link.split("=",1)[1]
            #print("divya", discount)
    address_ex = [item.text.split('\n')[1] for item in all_data.find_all('address', class_='address') ]
            #print("address", address_ex)
    quantity=[ indi.text for indi in all_data.find_all('span', class_='availability-status-indicator__text') ]
            #print("quantity", quantity)
    s=soup.find_all('div', class_='item-overview__meta-item')[1].text
  
#     sku_search = re.search('\nUPC:(.*)', s)
#     sku=sku_search.group(1)

    pages_dict =[ {"sku": '329264833', "zipcode":  address_ex[i].split()[-1], "priceoff": discount[i], \
                            "storeaddress" : ' '.join(address_ex[i].split()), \
                            "quantity": quantity[i] } for i in range(len(discount)) ]
            #for page in pages_dict:
            #    print(page) 
    print(pages_dict)
    
# except AttributeError: 
#         print("Sorry ! You are dividing by zero ")    
# except FileNotFoundError: 
#         print("File not found move on ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-044c398a0330> in <module>
#      16     discount=[ item.text for item in price_value ]
#      17     google_link = all_data.find_all('a', class_="address__link")[0]['href']
# ---> 18     gmaps_query.append(str(google_link.split("=",1)[1]))
#      19             #print("divya", discount)
#      20     address_ex = [item.text.split('\n')[1] for item in all_data.find_all('address', class_='address') ]
#
# AttributeError: 'str' object has no attribute 'append'

# %%
discount
# Out:
# ['2% off', '2% off', '2% off', '2% off', '75% off', '75% off']

# %%
with open("myresult_walmart", "w") as file:
    file.write(str(pages_dict))

# %%
 print(pages_dict)
# Out:
# [{'sku': '329264833', 'zipcode': '95661', 'priceoff': '88% off', 'storeaddress': '1400 Lead Hill BlvdRoseville CA', 'quantity': 'Limited Stock'}]

# %%
try:         
    
        soup = BeautifulSoup(read_from_html('html'+ zip_code +'.html'), 'html.parser')
        all_data = soup.find('div', class_="table inventory-checker-table inventory-checker-table--store-availability-price inventory-checker-table--columns-3")
        # .find('span', class_="table__cell-price-discount")
        price_value=all_data.find_all('span', class_='table__cell-price-discount')
        #print(price_value)  
        discount=[ item.text for item in price_value ]
        #print("divya", discount)
        address_ex = [item.text.split('\n')[1] for item in all_data.find_all('address', class_='address') ]
        #print("address", address_ex)
        quantity=[ indi.text for indi in all_data.find_all('span', class_='availability-status-indicator__text') ]
        #print("quantity", quantity)
        pages_dict = [ {"sku": sku, "zipcode:":  address_ex[i].split()[-1], "priceoff": discount[i], \
                        "storeaddress" : ' '.join(address_ex[i].split()[:-1]), \
                        "quantity": quantity[i] } for i in range(len(discount)) ]
        #for page in pages_dict:
        #    print(page) 
        return pages_dict 

    except AttributeError: 
        print("Sorry ! You are dividing by zero ")    
    except FileNotFoundError: 
        print("File not found move on ")
# Out:
# list

# %%
print(pages_dict)
# Out:
# [{'upc': '190198429612', 'zipcode': '95691-4957', 'priceoff': '50% off', 'storeaddress': '2005 Town Center Plz West Sacramento, CA', 'quantity': 'In Stock'}, {'upc': '190198429612', 'zipcode': '95834-2902', 'priceoff': '50% off', 'storeaddress': '3601 N Freeway Blvd Sacramento, CA', 'quantity': 'Limited Stock'}, {'upc': '190198429612', 'zipcode': '95825-1905', 'priceoff': '50% off', 'storeaddress': '1919 Fulton Ave Sacramento, CA', 'quantity': 'Out of Stock'}, {'upc': '190198429612', 'zipcode': '95818-2234', 'priceoff': '50% off', 'storeaddress': '2505 Riverside Blvd Sacramento, CA', 'quantity': 'Out of Stock'}, {'upc': '190198429612', 'zipcode': '95817-2611', 'priceoff': '50% off', 'storeaddress': '6507 4th Ave Sacramento, CA', 'quantity': 'Out of Stock'}, {'upc': '190198429612', 'zipcode': '95670-5646', 'priceoff': '50% off', 'storeaddress': '10881 Olson Dr Rancho Cordova, CA', 'quantity': 'Out of Stock'}, {'upc': '190198429612', 'zipcode': '95823-5415', 'priceoff': '50% off', 'sto
# ...

# %%
market_scraped_data = 'market_scraped_data'
connection = engine.raw_connection()
cursor = connection.cursor()
command = "DROP TABLE IF EXISTS {};".format(market_scraped_data)
cursor.execute(command)
connection.commit()
cursor.close()

# %%
rds_connection_string = "xsexllfzorcrvb:c19fdb9e7f8b1d787fd0aa79c53c274bd6b25e57c89b6d0981f8b6ad293a5c80@ec2-184-73-232-93.compute-1.amazonaws.com:5432/dbvr413t8b1dv6"
                      # "postgres://wyscmkyadpxnpq:4035077d37da67ed9b5c3f7d5a1560ed3adfda8c7e7a875df5139b38e8e5561e@ec2-54-83-201-84.compute-1.amazonaws.com:5432/d77gdrm2h45ur9"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
for every in pages_dict:
    print(every)
#     pages_data_df = pd.DataFrame(every)
#     pages_data_df.describe()
#     pages_data_df.to_sql('target_scraped_data', con=engine, index=False, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in pages_data_df})
# Out:
# {'upc': '190198429612', 'zipcode': '95691-4957', 'priceoff': '50% off', 'storeaddress': '2005 Town Center Plz West Sacramento, CA', 'quantity': 'In Stock'}
# {'upc': '190198429612', 'zipcode': '95834-2902', 'priceoff': '50% off', 'storeaddress': '3601 N Freeway Blvd Sacramento, CA', 'quantity': 'Limited Stock'}
# {'upc': '190198429612', 'zipcode': '95825-1905', 'priceoff': '50% off', 'storeaddress': '1919 Fulton Ave Sacramento, CA', 'quantity': 'Out of Stock'}
# {'upc': '190198429612', 'zipcode': '95818-2234', 'priceoff': '50% off', 'storeaddress': '2505 Riverside Blvd Sacramento, CA', 'quantity': 'Out of Stock'}
# {'upc': '190198429612', 'zipcode': '95817-2611', 'priceoff': '50% off', 'storeaddress': '6507 4th Ave Sacramento, CA', 'quantity': 'Out of Stock'}
# {'upc': '190198429612', 'zipcode': '95670-5646', 'priceoff': '50% off', 'storeaddress': '10881 Olson Dr Rancho Cordova, CA', 'quantity': 'Out of Stock'}
# ...

# %%
# for every in zip_codes:
#         page_dict_list.append(scrape_html_pages(every))

# %%
import pandas as pd
df = pd.read_json("myresult_walmart_iphone")

# %%
 df.to_sql('target_scraped_data', con=engine, index=False, if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in pages_data_df})

# %%
rds_connection_string = "bedlgjelgbrcba:62edbf5e39edf1ea129a38a5766d7354579374a6db487103a421c76fd47d78c3@ec2-184-73-232-93.compute-1.amazonaws.com:5432/dd4i4baf4sjibo"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
df.to_sql('market_scraped_data', con=engine, index=False,if_exists='append',dtype={col_name: sqlalchemy.types.VARCHAR for col_name in df})
